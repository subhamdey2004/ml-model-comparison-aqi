# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/processed/cleaned_data.csv")

df.head()
# Out:
#         City             Datetime   PM2.5    PM10    NO    NO2    NOx   NH3  \
# 0  Amaravati  2017-11-25 09:00:00  104.00  148.50  1.93  23.00  13.75  9.80
# 1  Amaravati  2017-11-25 10:00:00   94.50  142.00  1.33  16.25   9.75  9.65
# 2  Amaravati  2017-11-25 11:00:00   82.75  126.50  1.47  14.83   9.07  9.70
# 3  Amaravati  2017-11-25 14:00:00   68.50  117.00  1.35  13.60   8.35  7.40
# 4  Amaravati  2017-11-25 15:00:00   69.25  112.25  1.52  11.80   7.55  9.25
#
#     CO    SO2      O3  Benzene  Toluene  Xylene    AQI
# 0  0.1  15.30  117.62     0.30    10.40    0.23  155.0
# 1  0.1  17.00  136.23     0.28     7.10    0.15  159.0
# 2  0.1  15.40  149.92     0.20     4.55    0.08  173.0
# 3  0.1  21.80  161.70     0.10     2.30    0.00  191.0
# 4  0.1  21.38  161.68     0.10     2.35    0.00  191.0

# %%
df.shape
# Out:
# (53569, 15)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 53569 entries, 0 to 53568
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   City      53569 non-null  str
#  1   Datetime  53569 non-null  str
#  2   PM2.5     53569 non-null  float64
#  3   PM10      53569 non-null  float64
#  4   NO        53569 non-null  float64
#  5   NO2       53569 non-null  float64
#  6   NOx       53569 non-null  float64
#  7   NH3       53569 non-null  float64
#  8   CO        53569 non-null  float64
#  9   SO2       53569 non-null  float64
#  10  O3        53569 non-null  float64
#  11  Benzene   53569 non-null  float64
#  12  Toluene   53569 non-null  float64
#  13  Xylene    53569 non-null  float64
#  14  AQI       53569 non-null  float64
# dtypes: float64(13), str(2)
# memory usage: 6.1 MB

# %%
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  53569.000000  53569.000000  53569.000000  53569.000000  53569.000000
# mean      86.575431    168.796360     24.364661     33.050006     41.771323
# std       80.371181    126.214185     32.808752     24.022544     38.752347
# min        0.030000      2.000000      0.010000      0.130000      0.000000
# 25%       33.240000     76.430000      7.810000     13.210000     18.610000
# 50%       61.120000    132.500000     13.490000     27.420000     28.730000
# 75%      112.820000    227.150000     24.360000     45.650000     50.400000
# max      999.990000   1000.000000    287.720000    264.110000    392.860000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  53569.000000  53569.000000  53569.000000  53569.000000  53569.000000
# mean      30.957980      1.491005     12.588664     36.917647      3.449408
# std       21.946516      2.254609      9.190929     26.914558      3.375888
# min        0.010000      0.000000      0.010000      0.030000      0.000000
# 25%       13.010000      0.600000      7.620000     18.560000      1.350000
# 50%       29.350000      0.870000     10.780000     28.900000      2.520000
# 75%       40.980000      1.370000     15.420000     48.020000      4.500000
# max      485.520000     31.620000    195.000000    219.780000     91.100000
#
#             Toluene        Xylene           AQI
# count  53569.000000  53569.000000  53569.000000
# mean      13.277696      2.612119    189.636506
# std       18.225950      6.575336    120.351439
# min        0.000000      0.000000     21.000000
# 25%        1.890000      0.100000     92.000000
# 50%        6.230000      0.760000    152.000000
# 75%       17.840000      2.070000    282.000000
# max      165.050000    261.950000    760.000000

# %%
df.isnull().sum()
# Out:
# City        0
# Datetime    0
# PM2.5       0
# PM10        0
# NO          0
# NO2         0
# NOx         0
# NH3         0
# CO          0
# SO2         0
# O3          0
# Benzene     0
# Toluene     0
# Xylene      0
# AQI         0
# dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['AQI'], bins=50)
plt.title("AQI Distribution")
plt.show()

# %%
plt.figure(figsize=(12,8))
numeric_df = df.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(), cmap='coolwarm', annot=True)
plt.title("Feature Correlation")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(x=df['PM2.5'], y=df['AQI'])

plt.title("PM2.5 vs AQI")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df['AQI'], bins=50, kde=True)

plt.title("Distribution of AQI")
plt.xlabel("AQI")
plt.ylabel("Frequency")

plt.show()
